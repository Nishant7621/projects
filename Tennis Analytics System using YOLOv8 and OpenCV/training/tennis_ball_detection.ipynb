# %%
# !pip install roboflow
# !pip install ultralytics
# Out:
# ...
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="m7aUrfdkKOxvYSE8nmPE")

project = rf.workspace("nishant-jha-wbyic").project("tennis-ball-detection")
version = project.version(6)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# Cell In[3], line 6
#       4 project = rf.workspace("nishant-jha-wbyic").project("tennis-ball-detection")
#       5 version = project.version(6)
# ----> 6 dataset = version.download("yolov5")
#
# File c:\Users\nisha\AppData\Local\Programs\Python\Python313\Lib\site-packages\roboflow\core\version.py:253, in Version.download(self, model_format, location, overwrite)
#     250     link = export_info["export"]["link"]
#     252 self.__download_zip(link, location, model_format)
# --> 253 extract_zip(location, desc=f"Extracting Dataset Version Zip to {location} in {model_format}:")
#     254 self.__reformat_yaml(location, model_format)  # TODO: is roboflow-python a place to be munging yaml files?
# ...

# %%
import shutil
shutil.move("tennis-ball-detection-6/train",
"tennis-ball-detection-6/tennis-ball-detection-6/train",
)
shutil.move("tennis-ball-detection-6/test",
"tennis-ball-detection-6/tennis-ball-detection-6/test",
)
shutil.move("tennis-ball-detection-6/valid",
"tennis-ball-detection-6/tennis-ball-detection-6/valid",
)
# Out:
# 'tennis-ball-detection-6/tennis-ball-detection-6/valid'

# %%
# !yolo task=detect mode=train model=yolov5l6u.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
# Out:
# Traceback (most recent call last):
#   File "C:\Users\nisha\AppData\Local\Programs\Python\Python313\Lib\site-packages\ultralytics\engine\trainer.py", line 722, in get_dataset
#     data = check_det_dataset(self.args.data)
#   File "C:\Users\nisha\AppData\Local\Programs\Python\Python313\Lib\site-packages\ultralytics\data\utils.py", line 467, in check_det_dataset
#     file = Path(check_file(dataset))
#                 ~~~~~~~~~~^^^^^^^^^
#   File "C:\Users\nisha\AppData\Local\Programs\Python\Python313\Lib\site-packages\ultralytics\utils\checks.py", line 691, in check_file
#     raise FileNotFoundError(f"'{file}' does not exist")
# FileNotFoundError: '{dataset.location}/data.yaml' does not exist
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
# ...

# %%
import os

print(os.getcwd())
# Out:
# c:\Users\nisha\OneDrive\Desktop\sports project\training

# %%
print(c:\Users\nisha\OneDrive\Desktop\sports project\training)
# Out:
#   Cell In[8], line 1
#     print(c:\Users\nisha\OneDrive\Desktop\sports project\training)
#            ^
# SyntaxError: invalid syntax

# %%
# !yolo task=detect mode=train model=yolov8n.pt data="C:/Users/nisha/OneDrive/Desktop/sports project/training/ap-tennis-1/data.yaml" epochs=100 imgsz=640
# Out:
# ...
# New https://pypi.org/project/ultralytics/8.4.71 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.70  Python-3.13.9 torch-2.12.1+cpu CPU (AMD Ryzen 5 5500U with Radeon Graphics)
# ...
